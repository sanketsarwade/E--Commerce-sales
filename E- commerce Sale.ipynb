# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# adding csv file using pandas

# %%
df = pd.read_csv(r"C:\Users\SANKET\OneDrive\sanket project\Ecommerce Purchases")

# %%
df.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...

# %%
# Finding NUll values

# %%
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
# Finding Datatypes

# %%
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
df.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...

# %%
# Name of all columns

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
# all information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
# Max, Min, Mean

# %%
df['Purchase Price'].max()
# Out:
# 99.99

# %%
df['Purchase Price'].min()
# Out:
# 0.0

# %%
df['Purchase Price'].mean()
# Out:
# 50.347302

# %%
df.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...

# %%
# Number of engineers

# %%
len(df[df['Job'].str.contains('engineer', case= False)])
# Out:
# 984

# %%
# Number of Drilling Engineers

# %%
len(df[df['Job']== 'Drilling engineer'])
# Out:
# 21

# %%
# Most number of jobs persons have puchases more than 97

# %%
df2 = df[df['Purchase Price'] >= 97]['Job'].max()
df2
# Out:
# 'Youth worker'

# %%
# credit card = mastercard, purchase price more than 90, language= french

# %%
df[(df['Purchase Price'] >=90)& (df['Language']== 'fr')& (df['CC Provider']== 'Mastercard')]
# Out:
#                                                 Address    Lot AM or PM  \
# 2664  89433 Andrew Cape Apt. 070\nWest Amanda, WA 16...  26 FL       PM
# 2821  54256 Wilson Islands Suite 165\nShawnshire, PA...  88 oA       PM
# 2958       1274 Rubio Place\nIsaiahville, NY 31551-2817  77 ef       AM
# 3973  209 Mcclain Spur Suite 965\nPort Angelastad, A...  42 bW       PM
# 4347              Unit 3829 Box 1760\nDPO AA 62327-1931  44 Qy       AM
# 5651  669 William Ranch Suite 352\nDanielhaven, AL 8...  80 nw       AM
# 6263              PSC 1273, Box 3037\nAPO AA 11854-3422  93 HJ       PM
# 6865          7223 Michael Fields\nRoberttown, OK 51852  35 OM       PM
# 8980  640 Williams Highway\nNew Kennethtown, SC 0031...  81 Yn       PM
# 9297                   PSC 6924, Box 9684\nAPO AA 40806  24 Zf       PM
#
#                                            Browser Info  \
# 2664  Opera/9.68.(X11; Linux x86_64; it-IT) Presto/2...
# 2821  Opera/9.99.(Windows NT 5.1; en-US) Presto/2.9....
# ...

# %%
# job profession = Scientist, research (life sciences)

# %%
df[df['Job']== 'Scientist, research (life sciences)']
# Out:
#                                                 Address    Lot AM or PM  \
# 28    50533 Cooper Cliffs\nNorth Jonathanberg, MD 20482  17 kP       PM
# 1878        1188 Henry Knolls\nNorth Ryanport, AK 32829  43 lf       PM
# 2026  7047 Christensen Estates Suite 003\nPort Bethf...  09 Ch       AM
# 2050  7918 Cindy Turnpike Apt. 239\nSarahport, NH 66356  42 pP       AM
# 2727       4398 Caldwell Loop\nSouth Michelle, RI 28387  90 EU       PM
# 3617                          USS Johnson\nFPO AP 00291  06 ir       PM
# 3784  031 Ariel Summit Apt. 510\nLake Karenview, CA ...  36 dz       PM
# 3956      831 Lin Land\nEast Tiffanyland, ID 09083-6124  55 bw       PM
# 3960  44657 Anna Green Suite 251\nFrankland, LA 5512...  82 Id       AM
# 4003        152 Garcia Highway\nEast Jennifer, WV 66664  24 fl       AM
# 4257   537 Martin Shoals Suite 967\nJohnburgh, IN 62808  66 Ir       AM
# 4318              PSC 2572, Box 5579\nAPO AP 96906-3249  62 gx       PM
# ...

# %%
# list of job = scientist

# %%
df[df['Job'].str.contains('Scientist', case= False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 28    50533 Cooper Cliffs\nNorth Jonathanberg, MD 20482  17 kP       PM
# 70                Unit 9635 Box 0238\nDPO AE 55910-7730  76 NA       PM
# 114               Unit 0282 Box 9769\nDPO AP 05162-2277  72 zO       AM
# ...                                                 ...    ...      ...
# 9725     379 Derek Flats\nEast Juliestad, AR 17361-7304  86 Zu       PM
# 9826   2040 Bauer Plains\nNew Oliviafurt, OK 04192-8492  07 oo       PM
# 9876     4958 Richard Estate\nWilsontown, ME 19966-4472  30 su       PM
# 9923  313 Harris Drives Apt. 578\nTommyview, LA 1716...  15 VO       AM
# 9983              PSC 5678, Box 4503\nAPO AP 94998-5546  79 cd       AM
#
#                                            Browser Info  \
# ...

# %%
#time value counts

# %%
df['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
# Number of credit cards that expiring in 2022

# %%
def fun():
    count= 0
    for date in df['CC Exp Date']:
        if date.split('/')[1]=='22':
            count= count+1
    print(count)

# %%
fun()
# Out:
# 996

# %%
# credit card expiring in 2026

# %%
df[df['CC Exp Date'].apply(lambda x:x[3:]=='26')]
# Out:
#                                                 Address    Lot AM or PM  \
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 17    950 Jacqueline Village Apt. 592\nPort Kimberly...  23 Rh       PM
# 40    821 Adams Courts Apt. 568\nNorth Nicole, MS 03...  35 gn       AM
# 45    096 Edwards Valleys Suite 917\nPerkinsberg, LA...  07 Cd       PM
# ...                                                 ...    ...      ...
# 9928  210 Patterson Port Apt. 265\nHendrixbury, GA 7...  98 Cm       PM
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9965  2268 Austin Village Apt. 542\nWest Meghan, CA ...  03 hK       AM
# 9967            409 Holland Drives\nWhitetown, ME 78654  38 aX       AM
# 9974     500 Powell Rapid Apt. 114\nClarkfort, FL 70488  48 is       AM
#
#                                            Browser Info  \
# ...

# %%
# Finding most widely used email address

# %%
list0 = []
for email in df['Email']:
    list0.append(email.split('@')[1])

# %%
df['new'] = list0

# %%
df.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...

# %%
df['new'].value_counts()
# Out:
# hotmail.com            1638
# yahoo.com              1616
# gmail.com              1605
# smith.com                42
# williams.com             37
#                        ...
# booker.com                1
# woods-allen.biz           1
# richards-wilson.com       1
# morris-thomas.com         1
# wade-garner.com           1
# Name: new, Length: 3416, dtype: int64

# %%
#value count using lambda function

# %%
df['Email'].apply(lambda x:x.split('@')[1]).value_counts().head(10)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# brown.com         29
# johnson.com       29
# davis.com         25
# jones.com         25
# martinez.com      19
# Name: Email, dtype: int64
